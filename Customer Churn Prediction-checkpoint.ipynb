# %%
#import necessary libraries
#for data analysis
import pandas as pd
import numpy as np

#for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from collections import Counter

#for data pre processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

#Classifier librabries
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
# !pip install xgboost
#Ipip install xgboost
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

#Evaluation Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix
# !pip install missingno
import missingno as msno
import warnings
warnings.filterwarnings("ignore")

# %%
#load dataset
df=pd.read_csv(r"C:\Users\Daniel Omodunni\Downloads\Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#Categorical statistical analysis
df.describe(include=["object", "bool"])
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
#Visualize the missing data
plt.figure(figsize=(6,4))
sns.heatmap(df.isnull(), cbar=True, cmap="magma_r");

# %%
msno.bar(df, color="blue");

# %%
#to check for missing values
print(df.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#display where the missing data exists in the dataset
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#drop the missing data
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
unique_values = df['OnlineSecurity'].unique()
print(unique_values)
# Out:
# ['No' 'Yes' 'No internet service']

# %%
unique_values = df['OnlineBackup'].unique()
print(unique_values)
# Out:
# ['Yes' 'No' 'No internet service']

# %%
unique_values = df['DeviceProtection'].unique()
print(unique_values)
# Out:
# ['No' 'Yes' 'No internet service']

# %%
unique_values = df['TechSupport'].unique()
print(unique_values)
# Out:
# ['No' 'Yes' 'No internet service']

# %%
unique_values = df['StreamingTV'].unique()
print(unique_values)
# Out:
# ['No' 'Yes' 'No internet service']

# %%
unique_values = df['StreamingMovies'].unique()
print(unique_values)
# Out:
# ['No' 'Yes' 'No internet service']

# %%
unique_values = df['PaperlessBilling'].unique()
print(unique_values)
# Out:
# ['Yes' 'No']

# %%
unique_values = df['Churn'].unique()
print(unique_values)
# Out:
# ['No' 'Yes']

# %%
unique_values = df['Partner'].unique()
print(unique_values)
# Out:
# ['Yes' 'No']

# %%
unique_values = df['PhoneService'].unique()
print(unique_values)
# Out:
# ['No' 'Yes']

# %%
unique_values = df['Dependents'].unique()
print(unique_values)
# Out:
# ['No' 'Yes']

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['Dependents'].replace(['No', 'Yes'],
                        [0, 1], inplace=True)

# %%
df['PhoneService'].replace(['No', 'Yes'],
                        [0, 1], inplace=True)

# %%
df['Churn'].replace(['No', 'Yes'],
                        [0, 1], inplace=True)

# %%
df['Partner'].replace(['No', 'Yes'],
                        [0, 1], inplace=True)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                 int64
# dtype: object

# %% [markdown]
# # Univariate analysis

# %%
df.describe()
# Out:
#        SeniorCitizen      Partner   Dependents       tenure  PhoneService  \
# count    7043.000000  7043.000000  7043.000000  7043.000000   7043.000000
# mean        0.162147     0.483033     0.299588    32.371149      0.903166
# std         0.368612     0.499748     0.458110    24.559481      0.295752
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     9.000000      1.000000
# 50%         0.000000     0.000000     0.000000    29.000000      1.000000
# 75%         0.000000     1.000000     1.000000    55.000000      1.000000
# max         1.000000     1.000000     1.000000    72.000000      1.000000
#
#        MonthlyCharges        Churn
# count     7043.000000  7043.000000
# mean        64.761692     0.265370
# std         30.090047     0.441561
# min         18.250000     0.000000
# 25%         35.500000     0.000000
# 50%         70.350000     0.000000
# 75%         89.850000     1.000000
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#Grouping tenure
def tenure_bracket(tenure):
    if tenure <=35:
        return"<=25 Youth"
    elif tenure <=55:
        return"Adult(<=55)"
    elif tenure <=65:
        return "Old Adult(>=65)"
    else:
        return"Elders(>=65)"
df["tenure_bracket"]=df['tenure'].apply(tenure_bracket)
plt.figure(figsize=(10,5))
sns.countplot(x='tenure_bracket', data=df)
plt.xlabel('tenure_group')
plt.ylabel('Count of tenure_group')
plt.title('Total number of customer');

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
sns.boxplot(x=df['tenure']);

# %%
sns.boxplot(x=df['MonthlyCharges']);

# %%
#Total number of Customers
plt.figure(figsize=(10,5))
sns.countplot(x='gender', data=df)
plt.xlabel('Gender')
plt.ylabel('Count of Customer gender')
plt.title('Total number of Customers');

# %%
fig,ax=plt.subplots(figsize=(5,5))
count=Counter(df["gender"])
ax.pie(count.values(), labels=count.keys(),autopct=lambda p:f'{p:.2f}%');
ax.set_title("Percentage of transactions by Gender")
plt.show();

# %%
fig,ax=plt.subplots(figsize=(5,5))
count=Counter(df["SeniorCitizen"])
ax.pie(count.values(), labels=count.keys(),autopct=lambda p:f'{p:.2f}%');
ax.set_title("Percentage of Senior Citizens Customers")
plt.show();

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_bracket'],
#       dtype='object')

# %%
unique_values = df['Contract'].unique()
print(unique_values)
# Out:
# ['Month-to-month' 'One year' 'Two year']

# %%
ax=sns.countplot(x=df["Contract"], order=df["Contract"].value_counts(ascending=False).index)
values=df["Contract"].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0],labels=values);

# %%
#Total transactions by tenure bracket
plt.figure(figsize=(12,8))
ax=sns.countplot(y=df["tenure_bracket"], order=df["tenure_bracket"].value_counts(ascending=False).index)
values=df["tenure_bracket"].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0],labels=values);

# %% [markdown]
# # Bivariate analysis

# %%
# Subplots
fig,axs=plt.subplots(nrows=2, ncols=2,figsize=(15,10))
sns.boxplot(x="Dependents", data=df, ax=axs[0,0])
axs[0,0].set_title("Boxplot ondependents  ")
sns.histplot(x="PhoneService", data=df, ax=axs[0,1])
axs[0,1].set_title("Boxplot on phoneservice")
sns.boxplot(x="tenure", data=df, ax=axs[1,0])
axs[1,0].set_title("Boxplot on tenure")
sns.histplot(x="SeniorCitizen", data=df, ax=axs[1,1])
axs[1,1].set_title("Histogram of Senior citizen");

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_bracket'],
#       dtype='object')

# %%
def label(ch):
    if ch==1:
        return"Yes"
    else:
        return"No"
df["label"]=df['Churn'].apply(label)
plt.figure(figsize=(10,5))
sns.countplot(x='Churn', data=df)
plt.xlabel('Churn')
plt.ylabel('Count of Churned customers')
plt.title('Total number of Customers');

# %%
#investigating tenure brackets by churn feature
plt.figure(figsize=(10,5))
sns.countplot(x='tenure_bracket', data=df, hue='label')
plt.xlabel('Tenure_brackets')
plt.ylabel('Count of tenure_brackets')
plt.title('Total number of Churned Customers');

# %%
fig,axs=plt.subplots(nrows=2, ncols=3,figsize=(26,12))

gt=df.groupby("gender")["tenure"].sum().reset_index()
sns.barplot(x="gender",y="tenure", data=gt, ax=axs[0,0])
axs[0,0].set_title("Total tenure by Customer gender")

sd=df.groupby("StreamingTV")["Dependents"].sum().reset_index()
sns.barplot(x="StreamingTV",y="Dependents" ,data=sd, ax=axs[0,1])
axs[0,0].set_title("Total Steaming by Dependents")

tp=df.groupby("TotalCharges")["Partner"].sum().reset_index()
sns.barplot(x="TotalCharges",y="Partner", data=tp, ax=axs[0,2])
axs[0,0].set_title("Total charges for Partners")

pc=df.groupby("PhoneService")["Contract"].sum().reset_index()
sns.barplot(y="PhoneService",x="Contract" ,data=pc, ax=axs[1,0])
axs[0,0].set_title("Total phone service by contract")

si=df.groupby("SeniorCitizen")["InternetService"].sum().reset_index()
sns.barplot(y="SeniorCitizen",x="InternetService" ,data=si, ax=axs[1,1])
axs[0,0].set_title("Internet service by senior citizens")

sm=df.groupby("StreamingMovies")["MonthlyCharges"].sum().reset_index()
sns.barplot(y="StreamingMovies",x="MonthlyCharges", data=sm, ax=axs[1,2])
axs[0,0].set_title("Monthly charge of movie streaming");
# Out:
# Error in callback <function _draw_all_if_interactive at 0x00000209EEA713A0> (for post_execute):
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\Ijeoma\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\Ijeoma\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\Ijeoma\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# ...

# %% [markdown]
# Multivariate analysis

# %%
#Correlation

plt.figure(figsize= (10,10))
hm=sns.heatmap(df.corr(),square =True, annot=True, cbar=True, fmt='.2f', annot_kws= {'size':10});

# %%
#internet service against charges and churn
procat=df.groupby("InternetService")[['MonthlyCharges', 'TotalCharges', 'Churn']].sum().reset_index()
procat=pd.melt(procat, id_vars="InternetService", var_name="Metric", value_name="Total")
sns.barplot(data=procat, x="InternetService", y="Total", hue="Metric");

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_bracket', 'label'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='tenure_bracket', y='PhoneService', data=df, hue='label');

# %% [markdown]
# # Feature engineering/Data preprocessing

# %%
df.head()
#the created features which were created above are not needed, hence will be removed for this process
#create a copy of the data frame
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'tenure_bracket', 'label'],
#       dtype='object')

# %%
df1=df[['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']]
label=df[['Churn']]

# %%
df1.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df1['gender'].replace(['Female', 'Male'],
                        [0, 1], inplace=True)

# %%
df1.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
label.head()
#target which is the answer to the marking script label need s to be removed for predictions to be carried out properly and avoid overfitting
# Out:
#    Churn
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
df1.dtypes
# Out:
# customerID           object
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                 int64
# dtype: object

# %%
#dealing with outliers through data normalization
Scaler=MinMaxScaler()
df1['Scaled_PS']=Scaler.fit_transform(df1['PhoneService'].values.reshape(-1,1))
df1['Scaled_GN']=Scaler.fit_transform(df1['gender'].values.reshape(-1,1))
df1['Scaled_TN']=Scaler.fit_transform(df1['tenure'].values.reshape(-1,1))
df1['Scaled_DP']=Scaler.fit_transform(df1['Dependents'].values.reshape(-1,1))
df1['Scaled_MC']=Scaler.fit_transform(df1['MonthlyCharges'].values.reshape(-1,1))
df1.drop(['PhoneService','gender','tenure','Dependents','MonthlyCharges'],axis=1, inplace=True)
df1.head()
# Out:
#    customerID  SeniorCitizen  Partner     MultipleLines InternetService  \
# 0  7590-VHVEG              0        1  No phone service             DSL
# 1  5575-GNVDE              0        0                No             DSL
# 2  3668-QPYBK              0        0                No             DSL
# 3  7795-CFOCW              0        0  No phone service             DSL
# 4  9237-HQITU              0        0                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  ...  \
# 0             No          Yes               No          No          No  ...
# 1            Yes           No              Yes          No          No  ...
# 2            Yes          Yes               No          No          No  ...
# 3            Yes           No              Yes         Yes          No  ...
# 4             No           No               No          No          No  ...
#
# ...

# %%
#split the dataset into training and testing sets
x_train, x_test,y_train, y_test=train_test_split(df1, label, test_size=0.2, random_state=42)
#test size indicate the dataset to test and this represents 20%. Therefore 80% will be used for training

# %%
df1.shape
# Out:
# (7043, 21)

# %%
label.shape
# Out:
# (7043, 1)

# %%
x_train
# Out:
#       customerID  SeniorCitizen  Partner     MultipleLines InternetService  \
# 2142  4223-BKEOR              0        0                No             DSL
# 1623  6035-RIIOM              0        0               Yes     Fiber optic
# 6074  3797-VTIDR              0        1  No phone service             DSL
# 1362  2568-BRGYX              0        0                No     Fiber optic
# 6754  2775-SEFEE              0        0               Yes             DSL
# ...          ...            ...      ...               ...             ...
# 3772  0684-AOSIH              0        1                No     Fiber optic
# 5191  5982-PSMKW              0        1               Yes             DSL
# 5226  8044-BGWPI              0        1                No              No
# 5390  7450-NWRTR              1        0               Yes     Fiber optic
# 860   4795-UXVCJ              0        0                No              No
#
# ...

# %%
#practice
x_train.head()
# Out:
#       customerID  SeniorCitizen  Partner     MultipleLines InternetService  \
# 2142  4223-BKEOR              0        0                No             DSL
# 1623  6035-RIIOM              0        0               Yes     Fiber optic
# 6074  3797-VTIDR              0        1  No phone service             DSL
# 1362  2568-BRGYX              0        0                No     Fiber optic
# 6754  2775-SEFEE              0        0               Yes             DSL
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 2142            Yes           No              Yes          No          No
# 1623             No          Yes               No          No         Yes
# 6074             No           No               No          No          No
# 1362             No           No               No          No          No
# 6754            Yes          Yes               No         Yes          No
#
# ...

# %%
#answer
y_train.head()
# Out:
#       Churn
# 2142      0
# 1623      0
# 6074      1
# 1362      1
# 6754      0

# %%
df1.columns
# Out:
# Index(['customerID', 'SeniorCitizen', 'Partner', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn',
#        'Scaled_PS', 'Scaled_GN', 'Scaled_TN', 'Scaled_DP', 'Scaled_MC'],
#       dtype='object')

# %%
df1.drop(columns=['customerID','MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling','PaymentMethod'], inplace=True)

# %%
df1.drop(columns=['TotalCharges','Churn'])
# Out:
#       SeniorCitizen  Partner  Scaled_PS  Scaled_GN  Scaled_TN  Scaled_DP  \
# 0                 0        1        0.0        0.0   0.013889        0.0
# 1                 0        0        1.0        1.0   0.472222        0.0
# 2                 0        0        1.0        1.0   0.027778        0.0
# 3                 0        0        0.0        1.0   0.625000        0.0
# 4                 0        0        1.0        0.0   0.027778        0.0
# ...             ...      ...        ...        ...        ...        ...
# 7038              0        1        1.0        1.0   0.333333        1.0
# 7039              0        1        1.0        0.0   1.000000        1.0
# 7040              0        1        0.0        0.0   0.152778        1.0
# 7041              1        1        1.0        1.0   0.055556        0.0
# 7042              0        0        1.0        1.0   0.916667        0.0
#
#       Scaled_MC
# 0      0.115423
# 1      0.385075
# 2      0.354229
# 3      0.239303
# ...

# %%
#Model building using logistic regression
logreg=LogisticRegression()

logreg.fit(x_train, y_train)

ly_pred=logreg.predict(x_test)

print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test, ly_pred))
print("Precision:", precision_score(y_test, ly_pred))
print("Recall:", recall_score(y_test, ly_pred))
print("F1_score:", f1_score(y_test, ly_pred))
print("AUC_ROC:", roc_auc_score(y_test, ly_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 4
#       1 #Model building using logistic regression
#       2 logreg=LogisticRegression()
# ----> 4 logreg.fit(x_train, y_train)
#       6 ly_pred=logreg.predict(x_test)
#       8 print("Logistic Regression")
#
# File ~\anaconda3\Ijeoma\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Ijeoma\Lib\site-packages\sklearn\linear_model\_logistic.py:1207, in LogisticRegression.fit(self, X, y, sample_weight)
#    1204 else:
# ...
